# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of 2,000 random combinations of latitude and longitude
lats = np.random.uniform(-90,90,size =2000)
lngs = np.random.uniform(-180,180,size =2000)
lats_lngs = zip(lats,lngs)

# %%
coordinates = list(lats_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 784

# %%
# import dependencies
import requests
from configCopy1 import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval")
print("------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                         'Country': city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness': city_clouds,
                         'Wind Speed': city_wind,
                         'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass
    
print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of set 1 | tera
# Processing Record 2 of set 1 | alice springs
# Processing Record 3 of set 1 | jamestown
# Processing Record 4 of set 1 | honningsvag
# Processing Record 5 of set 1 | teya
# Processing Record 6 of set 1 | murgab
# Processing Record 7 of set 1 | rikitea
# Processing Record 8 of set 1 | cherskiy
# Processing Record 9 of set 1 | kirakira
# Processing Record 10 of set 1 | beyla
# Processing Record 11 of set 1 | puerto ayora
# Processing Record 12 of set 1 | los llanos de aridane
# Processing Record 13 of set 1 | goundam
# Processing Record 14 of set 1 | kaitangata
# Processing Record 15 of set 1 | hanmer springs
# Processing Record 16 of set 1 | hermanus
# Processing Record 17 of set 1 | hilo
# Processing Record 18 of set 1 | aklavik
# Processing Record 19 of set 1 | grand river south east
# City not found. Skipping...
# Processing Record 20 of set 1 | mar del plata
# Processing Record 21 of set 1 | bekasi
# Processing Record 22 of set 1 | youhao
# Processing Record 23 of set 1 | harnosand
# Processing Record 24 of set 1 | luderitz
# Processing Record 25 of set 1 | ribeira grande
# Processing Record 26 of set 1 | cabo san lucas
# Processing Record 27 of set 1 | ushuaia
# Processing Record 28 of set 1 | albany
# Processing Record 29 of set 1 | yate
# Processing Record 30 of set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of set 1 | dunedin
# Processing Record 32 of set 1 | santa barbara
# Processing Record 33 of set 1 | provideniya
# Processing Record 34 of set 1 | raiganj
# Processing Record 35 of set 1 | muriwai beach
# Processing Record 36 of set 1 | fairbanks
# Processing Record 37 of set 1 | lafiagi
# Processing Record 38 of set 1 | torbay
# Processing Record 39 of set 1 | pevek
# Processing Record 40 of set 1 | yellowknife
# Processing Record 41 of set 1 | rio gallegos
# Processing Record 42 of set 1 | chokurdakh
# Processing Record 43 of set 1 | stryn
# Processing Record 44 of set 1 | ambikapur
# Processing Record 45 of set 1 | murray bridge
# Processing Record 46 of set 1 | tahta
# Processing Record 47 of set 1 | acarau
# Processing Record 48 of set 1 | mataura
# Processing Record 49 of set 1 | sao joao da barra
# Processing Record 50 of set 1 | nuuk
# Processing Record 1 of set 2 | new norfolk
# Processing Record 2 of set 2 | shingu
# Processing Record 3 of set 2 | ust-kuyga
# Processing Record 4 of set 2 | mount gambier
# Processing Record 5 of set 2 | bandarbeyla
# Processing Record 6 of set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of set 2 | richmond
# Processing Record 8 of set 2 | south lake tahoe
# Processing Record 9 of set 2 | clyde river
# Processing Record 10 of set 2 | nikolskoye
# Processing Record 11 of set 2 | kapaa
# Processing Record 12 of set 2 | georgetown
# Processing Record 13 of set 2 | maralal
# Processing Record 14 of set 2 | taoudenni
# Processing Record 15 of set 2 | harlingen
# Processing Record 16 of set 2 | guerrero negro
# Processing Record 17 of set 2 | bengkulu
# Processing Record 18 of set 2 | saint-philippe
# Processing Record 19 of set 2 | codrington
# Processing Record 20 of set 2 | elk city
# Processing Record 21 of set 2 | tran
# Processing Record 22 of set 2 | cape town
# Processing Record 23 of set 2 | galesong
# Processing Record 24 of set 2 | tarakan
# Processing Record 25 of set 2 | la ronge
# Processing Record 26 of set 2 | klaksvik
# Processing Record 27 of set 2 | hami
# Processing Record 28 of set 2 | katsuura
# Processing Record 29 of set 2 | aswan
# Processing Record 30 of set 2 | mitsamiouli
# Processing Record 31 of set 2 | vaini
# Processing Record 32 of set 2 | allanmyo
# City not found. Skipping...
# Processing Record 33 of set 2 | hobart
# Processing Record 34 of set 2 | aldan
# Processing Record 35 of set 2 | broken hill
# Processing Record 36 of set 2 | bredasdorp
# Processing Record 37 of set 2 | gasa
# Processing Record 38 of set 2 | castro
# Processing Record 39 of set 2 | benguela
# Processing Record 40 of set 2 | edissiya
# Processing Record 41 of set 2 | alotau
# City not found. Skipping...
# Processing Record 42 of set 2 | sao filipe
# Processing Record 43 of set 2 | te anau
# Processing Record 44 of set 2 | natal
# Processing Record 45 of set 2 | salina cruz
# Processing Record 46 of set 2 | labuhan
# Processing Record 47 of set 2 | khatanga
# Processing Record 48 of set 2 | krasnoarmeysk
# Processing Record 49 of set 2 | deputatskiy
# Processing Record 50 of set 2 | carnarvon
# Processing Record 1 of set 3 | east london
# Processing Record 2 of set 3 | tuatapere
# Processing Record 3 of set 3 | butaritari
# Processing Record 4 of set 3 | chuy
# Processing Record 5 of set 3 | busselton
# Processing Record 6 of set 3 | padang
# Processing Record 7 of set 3 | okha
# Processing Record 8 of set 3 | hambantota
# Processing Record 9 of set 3 | jarjis
# City not found. Skipping...
# Processing Record 10 of set 3 | san cristobal
# Processing Record 11 of set 3 | beloha
# Processing Record 12 of set 3 | thompson
# Processing Record 13 of set 3 | resen
# Processing Record 14 of set 3 | srednekolymsk
# Processing Record 15 of set 3 | souillac
# Processing Record 16 of set 3 | tabory
# Processing Record 17 of set 3 | uyuni
# Processing Record 18 of set 3 | tupik
# Processing Record 19 of set 3 | sinjai
# Processing Record 20 of set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of set 3 | bethel
# Processing Record 22 of set 3 | wasilla
# Processing Record 23 of set 3 | ferme-neuve
# Processing Record 24 of set 3 | vila velha
# Processing Record 25 of set 3 | sarmanovo
# Processing Record 26 of set 3 | mulchen
# Processing Record 27 of set 3 | araguacu
# Processing Record 28 of set 3 | mayumba
# Processing Record 29 of set 3 | punta arenas
# Processing Record 30 of set 3 | mardan
# Processing Record 31 of set 3 | faanui
# Processing Record 32 of set 3 | tasiilaq
# Processing Record 33 of set 3 | veydelevka
# Processing Record 34 of set 3 | talnakh
# Processing Record 35 of set 3 | rocha
# Processing Record 36 of set 3 | champerico
# Processing Record 37 of set 3 | lebu
# Processing Record 38 of set 3 | bulaevo
# Processing Record 39 of set 3 | arraial do cabo
# Processing Record 40 of set 3 | namatanai
# Processing Record 41 of set 3 | ostrovnoy
# Processing Record 42 of set 3 | barrow
# Processing Record 43 of set 3 | flinders
# Processing Record 44 of set 3 | tome
# Processing Record 45 of set 3 | dakoro
# Processing Record 46 of set 3 | bluff
# Processing Record 47 of set 3 | esperance
# Processing Record 48 of set 3 | tecoanapa
# Processing Record 49 of set 3 | kodiak
# Processing Record 50 of set 3 | bairiki
# Processing Record 1 of set 4 | atuona
# Processing Record 2 of set 4 | oktyabrskiy
# Processing Record 3 of set 4 | tecpan
# Processing Record 4 of set 4 | muzhi
# Processing Record 5 of set 4 | muisne
# Processing Record 6 of set 4 | morro bay
# Processing Record 7 of set 4 | port alfred
# Processing Record 8 of set 4 | leshukonskoye
# Processing Record 9 of set 4 | aksu
# Processing Record 10 of set 4 | qaanaaq
# Processing Record 11 of set 4 | quipot
# Processing Record 12 of set 4 | longyearbyen
# Processing Record 13 of set 4 | ancud
# Processing Record 14 of set 4 | san policarpo
# Processing Record 15 of set 4 | muros
# Processing Record 16 of set 4 | cabatuan
# Processing Record 17 of set 4 | lata
# Processing Record 18 of set 4 | linguere
# Processing Record 19 of set 4 | lujan
# Processing Record 20 of set 4 | west wendover
# Processing Record 21 of set 4 | ponta do sol
# Processing Record 22 of set 4 | sinnamary
# Processing Record 23 of set 4 | port elizabeth
# Processing Record 24 of set 4 | bambous virieux
# Processing Record 25 of set 4 | laguna
# Processing Record 26 of set 4 | novoagansk
# Processing Record 27 of set 4 | dikson
# Processing Record 28 of set 4 | graham
# Processing Record 29 of set 4 | djenne
# Processing Record 30 of set 4 | kaduy
# Processing Record 31 of set 4 | ibra
# Processing Record 32 of set 4 | hasaki
# Processing Record 33 of set 4 | babanusah
# City not found. Skipping...
# Processing Record 34 of set 4 | douala
# Processing Record 35 of set 4 | high level
# Processing Record 36 of set 4 | waipawa
# Processing Record 37 of set 4 | dzhebariki-khaya
# Processing Record 38 of set 4 | lukulu
# Processing Record 39 of set 4 | warqla
# City not found. Skipping...
# Processing Record 40 of set 4 | biak
# Processing Record 41 of set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of set 4 | noshiro
# Processing Record 43 of set 4 | yanchukan
# City not found. Skipping...
# Processing Record 44 of set 4 | sisimiut
# Processing Record 45 of set 4 | price
# Processing Record 46 of set 4 | tiksi
# Processing Record 47 of set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of set 4 | pacific grove
# Processing Record 49 of set 4 | buala
# Processing Record 50 of set 4 | hithadhoo
# Processing Record 1 of set 5 | naze
# Processing Record 2 of set 5 | palu
# Processing Record 3 of set 5 | launceston
# Processing Record 4 of set 5 | barcelona
# Processing Record 5 of set 5 | alekseyevskoye
# Processing Record 6 of set 5 | okhotsk
# Processing Record 7 of set 5 | kyabe
# Processing Record 8 of set 5 | mahebourg
# Processing Record 9 of set 5 | pa daet
# Processing Record 10 of set 5 | richards bay
# Processing Record 11 of set 5 | matagalpa
# Processing Record 12 of set 5 | wyszkow
# Processing Record 13 of set 5 | qunduz
# Processing Record 14 of set 5 | alugan
# Processing Record 15 of set 5 | grimshaw
# Processing Record 16 of set 5 | saleaula
# City not found. Skipping...
# Processing Record 17 of set 5 | imbituba
# Processing Record 18 of set 5 | maridi
# Processing Record 19 of set 5 | pisco
# Processing Record 20 of set 5 | chapleau
# Processing Record 21 of set 5 | vallenar
# Processing Record 22 of set 5 | port blair
# Processing Record 23 of set 5 | maiduguri
# Processing Record 24 of set 5 | ciudad del maiz
# Processing Record 25 of set 5 | vaitupu
# City not found. Skipping...
# Processing Record 26 of set 5 | luanda
# Processing Record 27 of set 5 | port moresby
# Processing Record 28 of set 5 | kieta
# Processing Record 29 of set 5 | state college
# Processing Record 30 of set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of set 5 | dudinka
# Processing Record 32 of set 5 | nizhniy tsasuchey
# Processing Record 33 of set 5 | bluefields
# Processing Record 34 of set 5 | doha
# Processing Record 35 of set 5 | cayenne
# Processing Record 36 of set 5 | tuktoyaktuk
# Processing Record 37 of set 5 | grindavik
# Processing Record 38 of set 5 | lagoa
# Processing Record 39 of set 5 | gat
# Processing Record 40 of set 5 | geraldton
# Processing Record 41 of set 5 | victoria
# Processing Record 42 of set 5 | istanbul
# Processing Record 43 of set 5 | skjervoy
# Processing Record 44 of set 5 | norman wells
# Processing Record 45 of set 5 | severo-kurilsk
# Processing Record 46 of set 5 | kruisfontein
# Processing Record 47 of set 5 | forbes
# Processing Record 48 of set 5 | matagami
# Processing Record 49 of set 5 | avarua
# Processing Record 50 of set 5 | rafraf
# Processing Record 1 of set 6 | port lincoln
# Processing Record 2 of set 6 | mountain home
# Processing Record 3 of set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of set 6 | gazanjyk
# Processing Record 5 of set 6 | glossa
# Processing Record 6 of set 6 | mapiri
# Processing Record 7 of set 6 | abu samrah
# Processing Record 8 of set 6 | the valley
# Processing Record 9 of set 6 | tabatinga
# Processing Record 10 of set 6 | saskylakh
# Processing Record 11 of set 6 | airai
# Processing Record 12 of set 6 | mucurapo
# Processing Record 13 of set 6 | hailar
# Processing Record 14 of set 6 | freiberg
# Processing Record 15 of set 6 | shihezi
# Processing Record 16 of set 6 | jackson
# Processing Record 17 of set 6 | toliary
# City not found. Skipping...
# Processing Record 18 of set 6 | tawkar
# City not found. Skipping...
# Processing Record 19 of set 6 | constitucion
# Processing Record 20 of set 6 | krasnovishersk
# Processing Record 21 of set 6 | colac
# Processing Record 22 of set 6 | leningradskiy
# Processing Record 23 of set 6 | udachnyy
# Processing Record 24 of set 6 | sola
# Processing Record 25 of set 6 | karratha
# Processing Record 26 of set 6 | loubomo
# Processing Record 27 of set 6 | eisiskes
# Processing Record 28 of set 6 | quatre cocos
# Processing Record 29 of set 6 | touros
# Processing Record 30 of set 6 | russell
# Processing Record 31 of set 6 | nabire
# Processing Record 32 of set 6 | suntar
# Processing Record 33 of set 6 | ampanihy
# Processing Record 34 of set 6 | glendive
# Processing Record 35 of set 6 | mbandaka
# Processing Record 36 of set 6 | vuktyl
# Processing Record 37 of set 6 | wadi musa
# Processing Record 38 of set 6 | marcona
# City not found. Skipping...
# Processing Record 39 of set 6 | tiznit
# Processing Record 40 of set 6 | porbandar
# Processing Record 41 of set 6 | surt
# Processing Record 42 of set 6 | maple creek
# Processing Record 43 of set 6 | wicklow
# Processing Record 44 of set 6 | wolsztyn
# Processing Record 45 of set 6 | adrar
# Processing Record 46 of set 6 | samusu
# City not found. Skipping...
# Processing Record 47 of set 6 | porto novo
# Processing Record 48 of set 6 | lixourion
# Processing Record 49 of set 6 | wanning
# Processing Record 50 of set 6 | vanimo
# Processing Record 1 of set 7 | aras
# Processing Record 2 of set 7 | sindgi
# Processing Record 3 of set 7 | howard springs
# Processing Record 4 of set 7 | oskemen
# Processing Record 5 of set 7 | bajo baudo
# City not found. Skipping...
# Processing Record 6 of set 7 | narsaq
# Processing Record 7 of set 7 | arlit
# Processing Record 8 of set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of set 7 | tynda
# Processing Record 10 of set 7 | shenjiamen
# Processing Record 11 of set 7 | upernavik
# Processing Record 12 of set 7 | dalby
# Processing Record 13 of set 7 | gazimurskiy zavod
# Processing Record 14 of set 7 | olafsvik
# Processing Record 15 of set 7 | pangnirtung
# Processing Record 16 of set 7 | flin flon
# Processing Record 17 of set 7 | belushya guba
# City not found. Skipping...
# Processing Record 18 of set 7 | hay river
# Processing Record 19 of set 7 | cidreira
# Processing Record 20 of set 7 | qaqortoq
# Processing Record 21 of set 7 | havre-saint-pierre
# Processing Record 22 of set 7 | hualmay
# Processing Record 23 of set 7 | port hawkesbury
# Processing Record 24 of set 7 | mouila
# Processing Record 25 of set 7 | portland
# Processing Record 26 of set 7 | alofi
# Processing Record 27 of set 7 | tupelo
# Processing Record 28 of set 7 | tsihombe
# City not found. Skipping...
# Processing Record 29 of set 7 | inirida
# Processing Record 30 of set 7 | dicabisagan
# Processing Record 31 of set 7 | coolum beach
# Processing Record 32 of set 7 | mitu
# Processing Record 33 of set 7 | petropavlovsk-kamchatskiy
# Processing Record 34 of set 7 | khorramshahr
# Processing Record 35 of set 7 | merauke
# Processing Record 36 of set 7 | manaus
# Processing Record 37 of set 7 | avera
# Processing Record 38 of set 7 | kyra
# Processing Record 39 of set 7 | port keats
# Processing Record 40 of set 7 | lompoc
# Processing Record 41 of set 7 | atar
# Processing Record 42 of set 7 | nizwa
# Processing Record 43 of set 7 | karamea
# City not found. Skipping...
# Processing Record 44 of set 7 | nantucket
# Processing Record 45 of set 7 | sibiti
# Processing Record 46 of set 7 | verkhnyaya inta
# Processing Record 47 of set 7 | labutta
# City not found. Skipping...
# Processing Record 48 of set 7 | kalmunai
# Processing Record 49 of set 7 | sur
# Processing Record 50 of set 7 | sakakah
# Processing Record 1 of set 8 | port hardy
# Processing Record 2 of set 8 | astoria
# Processing Record 3 of set 8 | bajil
# Processing Record 4 of set 8 | mrirt
# City not found. Skipping...
# Processing Record 5 of set 8 | mecca
# Processing Record 6 of set 8 | bella union
# Processing Record 7 of set 8 | basco
# Processing Record 8 of set 8 | bay roberts
# Processing Record 9 of set 8 | nouakchott
# Processing Record 10 of set 8 | kindersley
# Processing Record 11 of set 8 | castelo
# Processing Record 12 of set 8 | ambrolauri
# Processing Record 13 of set 8 | barra do garcas
# Processing Record 14 of set 8 | boa vista
# Processing Record 15 of set 8 | janauba
# Processing Record 16 of set 8 | san francisco de macoris
# Processing Record 17 of set 8 | fuerte olimpo
# Processing Record 18 of set 8 | nanortalik
# Processing Record 19 of set 8 | batemans bay
# Processing Record 20 of set 8 | bubaque
# Processing Record 21 of set 8 | pierre
# Processing Record 22 of set 8 | sioux lookout
# Processing Record 23 of set 8 | hastings
# Processing Record 24 of set 8 | terrasini
# Processing Record 25 of set 8 | sorland
# Processing Record 26 of set 8 | coquimbo
# Processing Record 27 of set 8 | araouane
# Processing Record 28 of set 8 | nelson bay
# Processing Record 29 of set 8 | copiapo
# Processing Record 30 of set 8 | malakal
# Processing Record 31 of set 8 | saint anthony
# Processing Record 32 of set 8 | verkhoyansk
# Processing Record 33 of set 8 | kanigiri
# Processing Record 34 of set 8 | fez
# Processing Record 35 of set 8 | grand-bourg
# Processing Record 36 of set 8 | jiddah
# City not found. Skipping...
# Processing Record 37 of set 8 | itaituba
# Processing Record 38 of set 8 | pinawa
# Processing Record 39 of set 8 | nur
# Processing Record 40 of set 8 | amderma
# City not found. Skipping...
# Processing Record 41 of set 8 | abu dhabi
# Processing Record 42 of set 8 | pergamino
# Processing Record 43 of set 8 | vao
# Processing Record 44 of set 8 | moron
# Processing Record 45 of set 8 | bardstown
# Processing Record 46 of set 8 | dingle
# Processing Record 47 of set 8 | kutum
# Processing Record 48 of set 8 | sibolga
# Processing Record 49 of set 8 | barentsburg
# City not found. Skipping...
# Processing Record 50 of set 8 | dogondoutchi
# Processing Record 1 of set 9 | edd
# Processing Record 2 of set 9 | shkotovo-22
# City not found. Skipping...
# Processing Record 3 of set 9 | tadine
# Processing Record 4 of set 9 | chaiya
# Processing Record 5 of set 9 | bogorodskoye
# Processing Record 6 of set 9 | patti
# Processing Record 7 of set 9 | wonthaggi
# Processing Record 8 of set 9 | la paz
# Processing Record 9 of set 9 | bardiyah
# Processing Record 10 of set 9 | tazovskiy
# Processing Record 11 of set 9 | japura
# Processing Record 12 of set 9 | aksarayskiy
# Processing Record 13 of set 9 | andenes
# Processing Record 14 of set 9 | jinka
# Processing Record 15 of set 9 | poya
# Processing Record 16 of set 9 | mantua
# Processing Record 17 of set 9 | tsiroanomandidy
# Processing Record 18 of set 9 | maldonado
# Processing Record 19 of set 9 | vardo
# Processing Record 20 of set 9 | nata
# Processing Record 21 of set 9 | mayskiy
# Processing Record 22 of set 9 | tessalit
# Processing Record 23 of set 9 | tiarei
# Processing Record 24 of set 9 | salalah
# Processing Record 25 of set 9 | carauari
# Processing Record 26 of set 9 | donskoye
# Processing Record 27 of set 9 | camabatela
# Processing Record 28 of set 9 | soyo
# Processing Record 29 of set 9 | walvis bay
# Processing Record 30 of set 9 | gizo
# Processing Record 31 of set 9 | terney
# Processing Record 32 of set 9 | beringovskiy
# Processing Record 33 of set 9 | rudbar
# Processing Record 34 of set 9 | ubinskoye
# Processing Record 35 of set 9 | manga
# Processing Record 36 of set 9 | lavrentiya
# Processing Record 37 of set 9 | port macquarie
# Processing Record 38 of set 9 | farah
# Processing Record 39 of set 9 | iqaluit
# Processing Record 40 of set 9 | diapaga
# Processing Record 41 of set 9 | kununurra
# Processing Record 42 of set 9 | diamantino
# Processing Record 43 of set 9 | bontang
# Processing Record 44 of set 9 | san pedro
# Processing Record 45 of set 9 | jabinyanah
# Processing Record 46 of set 9 | kudchi
# City not found. Skipping...
# Processing Record 47 of set 9 | volkhov
# Processing Record 48 of set 9 | vestmanna
# Processing Record 49 of set 9 | hofn
# Processing Record 50 of set 9 | kirkuk
# Processing Record 1 of set 10 | paracuru
# Processing Record 2 of set 10 | lodja
# Processing Record 3 of set 10 | tautira
# Processing Record 4 of set 10 | kursk
# Processing Record 5 of set 10 | katobu
# Processing Record 6 of set 10 | grand gaube
# Processing Record 7 of set 10 | havelock
# Processing Record 8 of set 10 | san patricio
# Processing Record 9 of set 10 | melbu
# Processing Record 10 of set 10 | birnin kebbi
# Processing Record 11 of set 10 | warrington
# Processing Record 12 of set 10 | cileungsi
# Processing Record 13 of set 10 | benxi
# Processing Record 14 of set 10 | chambas
# Processing Record 15 of set 10 | mariental
# Processing Record 16 of set 10 | beni mazar
# Processing Record 17 of set 10 | cockburn town
# Processing Record 18 of set 10 | maraba
# Processing Record 19 of set 10 | einbeck
# Processing Record 20 of set 10 | mergui
# City not found. Skipping...
# Processing Record 21 of set 10 | doume
# Processing Record 22 of set 10 | hengyang
# Processing Record 23 of set 10 | revda
# Processing Record 24 of set 10 | kalengwa
# Processing Record 25 of set 10 | birzai
# Processing Record 26 of set 10 | zeya
# Processing Record 27 of set 10 | asau
# Processing Record 28 of set 10 | riyadh
# Processing Record 29 of set 10 | husavik
# Processing Record 30 of set 10 | chumikan
# Processing Record 31 of set 10 | sitka
# Processing Record 32 of set 10 | joensuu
# Processing Record 33 of set 10 | tir pol
# City not found. Skipping...
# Processing Record 34 of set 10 | salinas
# Processing Record 35 of set 10 | sahrak
# City not found. Skipping...
# Processing Record 36 of set 10 | macusani
# Processing Record 37 of set 10 | finschhafen
# Processing Record 38 of set 10 | linhares
# Processing Record 39 of set 10 | kosonsoy
# Processing Record 40 of set 10 | sassandra
# Processing Record 41 of set 10 | kavaratti
# Processing Record 42 of set 10 | muli
# Processing Record 43 of set 10 | abhar
# Processing Record 44 of set 10 | poum
# Processing Record 45 of set 10 | majene
# Processing Record 46 of set 10 | nizhneangarsk
# Processing Record 47 of set 10 | agadez
# Processing Record 48 of set 10 | maniitsoq
# Processing Record 49 of set 10 | jawar
# Processing Record 50 of set 10 | kota bahru
# Processing Record 1 of set 11 | cacoal
# Processing Record 2 of set 11 | meulaboh
# Processing Record 3 of set 11 | puerto lumbreras
# Processing Record 4 of set 11 | progreso
# Processing Record 5 of set 11 | aqtobe
# Processing Record 6 of set 11 | cascais
# Processing Record 7 of set 11 | windsor
# Processing Record 8 of set 11 | bomi
# Processing Record 9 of set 11 | eureka
# Processing Record 10 of set 11 | kretinga
# Processing Record 11 of set 11 | amga
# Processing Record 12 of set 11 | odweyne
# Processing Record 13 of set 11 | lamu
# Processing Record 14 of set 11 | haibowan
# City not found. Skipping...
# Processing Record 15 of set 11 | coihaique
# Processing Record 16 of set 11 | vila franca do campo
# Processing Record 17 of set 11 | yeppoon
# Processing Record 18 of set 11 | zaplyusye
# City not found. Skipping...
# Processing Record 19 of set 11 | ahmadpur east
# Processing Record 20 of set 11 | newcastleton
# Processing Record 21 of set 11 | dwarka
# Processing Record 22 of set 11 | montepuez
# Processing Record 23 of set 11 | dongsheng
# Processing Record 24 of set 11 | faya
# Processing Record 25 of set 11 | ilulissat
# Processing Record 26 of set 11 | myski
# Processing Record 27 of set 11 | shahgarh
# Processing Record 28 of set 11 | arica
# Processing Record 29 of set 11 | denpasar
# Processing Record 30 of set 11 | bud
# Processing Record 31 of set 11 | ipixuna
# Processing Record 32 of set 11 | nova olinda do norte
# Processing Record 33 of set 11 | seoul
# Processing Record 34 of set 11 | ucluelet
# Processing Record 35 of set 11 | aykhal
# Processing Record 36 of set 11 | korla
# Processing Record 37 of set 11 | huber heights
# Processing Record 38 of set 11 | huilong
# Processing Record 39 of set 11 | ust-barguzin
# Processing Record 40 of set 11 | baijiantan
# Processing Record 41 of set 11 | brahmapuri
# City not found. Skipping...
# Processing Record 42 of set 11 | bela vista do paraiso
# Processing Record 43 of set 11 | kastamonu
# Processing Record 44 of set 11 | rafaela
# Processing Record 45 of set 11 | tommot
# Processing Record 46 of set 11 | satipo
# Processing Record 47 of set 11 | amuntai
# Processing Record 48 of set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of set 11 | cabedelo
# Processing Record 50 of set 11 | aloleng
# Processing Record 1 of set 12 | saint-augustin
# Processing Record 2 of set 12 | arrecife
# Processing Record 3 of set 12 | lolua
# City not found. Skipping...
# Processing Record 4 of set 12 | akhmeta
# Processing Record 5 of set 12 | oranjemund
# Processing Record 6 of set 12 | rawlins
# Processing Record 7 of set 12 | nara
# Processing Record 8 of set 12 | sao felix do xingu
# Processing Record 9 of set 12 | santa lucia
# Processing Record 10 of set 12 | saint george
# Processing Record 11 of set 12 | iglesias
# Processing Record 12 of set 12 | itarema
# Processing Record 13 of set 12 | ngunguru
# Processing Record 14 of set 12 | bilibino
# Processing Record 15 of set 12 | matamoros
# Processing Record 16 of set 12 | raton
# Processing Record 17 of set 12 | sistranda
# Processing Record 18 of set 12 | taltal
# Processing Record 19 of set 12 | isangel
# Processing Record 20 of set 12 | tuggurt
# City not found. Skipping...
# Processing Record 21 of set 12 | lasa
# Processing Record 22 of set 12 | dickinson
# Processing Record 23 of set 12 | aksarka
# Processing Record 24 of set 12 | ha giang
# Processing Record 25 of set 12 | kaniama
# Processing Record 26 of set 12 | salinopolis
# Processing Record 27 of set 12 | ambilobe
# Processing Record 28 of set 12 | dungarpur
# Processing Record 29 of set 12 | sarangani
# Processing Record 30 of set 12 | strezhevoy
# Processing Record 31 of set 12 | sobolevo
# Processing Record 32 of set 12 | vanavara
# Processing Record 33 of set 12 | west bay
# Processing Record 34 of set 12 | yashalta
# Processing Record 35 of set 12 | kahului
# Processing Record 36 of set 12 | palmer
# Processing Record 37 of set 12 | quime
# Processing Record 38 of set 12 | klaeng
# Processing Record 39 of set 12 | tumannyy
# City not found. Skipping...
# Processing Record 40 of set 12 | cap malheureux
# Processing Record 41 of set 12 | westport
# Processing Record 42 of set 12 | gamba
# Processing Record 43 of set 12 | paamiut
# Processing Record 44 of set 12 | ulladulla
# Processing Record 45 of set 12 | jiazi
# Processing Record 46 of set 12 | forrest city
# Processing Record 47 of set 12 | hirara
# Processing Record 48 of set 12 | bukachacha
# Processing Record 49 of set 12 | sambava
# Processing Record 50 of set 12 | xapuri
# Processing Record 1 of set 13 | palora
# Processing Record 2 of set 13 | tateyama
# Processing Record 3 of set 13 | port-gentil
# Processing Record 4 of set 13 | roald
# Processing Record 5 of set 13 | aragats
# Processing Record 6 of set 13 | bathsheba
# Processing Record 7 of set 13 | san quintin
# Processing Record 8 of set 13 | raudeberg
# Processing Record 9 of set 13 | mormugao
# Processing Record 10 of set 13 | joao pinheiro
# Processing Record 11 of set 13 | sherbakul
# Processing Record 12 of set 13 | baiyin
# Processing Record 13 of set 13 | veraval
# Processing Record 14 of set 13 | sompeta
# Processing Record 15 of set 13 | mnogovershinnyy
# Processing Record 16 of set 13 | bull savanna
# Processing Record 17 of set 13 | paris
# Processing Record 18 of set 13 | pingliang
# Processing Record 19 of set 13 | paita
# Processing Record 20 of set 13 | siderno
# Processing Record 21 of set 13 | nyimba
# Processing Record 22 of set 13 | kaspiysk
# Processing Record 23 of set 13 | arman
# Processing Record 24 of set 13 | harper
# Processing Record 25 of set 13 | moussoro
# Processing Record 26 of set 13 | egvekinot
# Processing Record 27 of set 13 | whitehorse
# Processing Record 28 of set 13 | ketchikan
# Processing Record 29 of set 13 | ayame
# Processing Record 30 of set 13 | kjollefjord
# Processing Record 31 of set 13 | tamandare
# Processing Record 32 of set 13 | vostok
# Processing Record 33 of set 13 | sao geraldo do araguaia
# Processing Record 34 of set 13 | pandamatenga
# Processing Record 35 of set 13 | peterhead
# Processing Record 36 of set 13 | zarubino
# Processing Record 37 of set 13 | kavieng
# Processing Record 38 of set 13 | zatoka
# Processing Record 39 of set 13 | palmares do sul
# Processing Record 40 of set 13 | halalo
# City not found. Skipping...
# Processing Record 41 of set 13 | karamken
# City not found. Skipping...
# Processing Record 42 of set 13 | saldanha
# Processing Record 43 of set 13 | manokwari
# Processing Record 44 of set 13 | qui nhon
# Processing Record 45 of set 13 | novobirilyussy
# Processing Record 46 of set 13 | isabela
# Processing Record 47 of set 13 | college
# Processing Record 48 of set 13 | turayf
# Processing Record 49 of set 13 | ntoum
# Processing Record 50 of set 13 | cloquet
# Processing Record 1 of set 14 | viedma
# Processing Record 2 of set 14 | varna
# Processing Record 3 of set 14 | bokspits
# City not found. Skipping...
# Processing Record 4 of set 14 | marrakesh
# Processing Record 5 of set 14 | pauini
# Processing Record 6 of set 14 | cabral
# Processing Record 7 of set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of set 14 | broome
# Processing Record 9 of set 14 | sokoni
# Processing Record 10 of set 14 | khandyga
# Processing Record 11 of set 14 | daru
# Processing Record 12 of set 14 | pimentel
# Processing Record 13 of set 14 | sikasso
# Processing Record 14 of set 14 | hermiston
# Processing Record 15 of set 14 | ormara
# Processing Record 16 of set 14 | somanda
# Processing Record 17 of set 14 | mount isa
# Processing Record 18 of set 14 | hukuntsi
# Processing Record 19 of set 14 | phalaborwa
# Processing Record 20 of set 14 | chany
# Processing Record 21 of set 14 | eyl
# Processing Record 22 of set 14 | terenos
# Processing Record 23 of set 14 | stornoway
# Processing Record 24 of set 14 | santa-maria
# Processing Record 25 of set 14 | morshansk
# Processing Record 26 of set 14 | le mans
# Processing Record 27 of set 14 | qafsah
# City not found. Skipping...
# Processing Record 28 of set 14 | stodolishche
# Processing Record 29 of set 14 | amahai
# Processing Record 30 of set 14 | paradwip
# City not found. Skipping...
# Processing Record 31 of set 14 | teguldet
# Processing Record 32 of set 14 | redwater
# Processing Record 33 of set 14 | yanan
# City not found. Skipping...
# Processing Record 34 of set 14 | kikwit
# Processing Record 35 of set 14 | wenshang
# Processing Record 36 of set 14 | samarinda
# Processing Record 37 of set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 38 of set 14 | cap-aux-meules
# Processing Record 39 of set 14 | san bartolome de tirajana
# Processing Record 40 of set 14 | badhni kalan
# Processing Record 41 of set 14 | namtsy
# Processing Record 42 of set 14 | sidney
# Processing Record 43 of set 14 | bikaner
# Processing Record 44 of set 14 | haines junction
# Processing Record 45 of set 14 | lingao
# Processing Record 46 of set 14 | telgte
# Processing Record 47 of set 14 | virginia beach
# Processing Record 48 of set 14 | kamwenge
# Processing Record 49 of set 14 | nicoya
# Processing Record 50 of set 14 | makakilo city
# Processing Record 1 of set 15 | qiongshan
# Processing Record 2 of set 15 | lerwick
# Processing Record 3 of set 15 | greenville
# Processing Record 4 of set 15 | garowe
# Processing Record 5 of set 15 | gurskoye
# City not found. Skipping...
# Processing Record 6 of set 15 | nome
# Processing Record 7 of set 15 | saint-francois
# Processing Record 8 of set 15 | los algarrobos
# Processing Record 9 of set 15 | esso
# Processing Record 10 of set 15 | foz
# Processing Record 11 of set 15 | shiraoi
# Processing Record 12 of set 15 | lengshuitan
# Processing Record 13 of set 15 | kaka
# Processing Record 14 of set 15 | belozerskoye
# Processing Record 15 of set 15 | louisbourg
# City not found. Skipping...
# Processing Record 16 of set 15 | dridu
# Processing Record 17 of set 15 | kandrian
# Processing Record 18 of set 15 | pangkalanbuun
# Processing Record 19 of set 15 | santo estevao
# Processing Record 20 of set 15 | plettenberg bay
# Processing Record 21 of set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 22 of set 15 | chimore
# Processing Record 23 of set 15 | chizhou
# Processing Record 24 of set 15 | louis trichardt
# Processing Record 25 of set 15 | tabialan
# City not found. Skipping...
# Processing Record 26 of set 15 | tezu
# Processing Record 27 of set 15 | changping
# Processing Record 28 of set 15 | bestobe
# Processing Record 29 of set 15 | hokitika
# Processing Record 30 of set 15 | camacha
# Processing Record 31 of set 15 | santiago de cao
# Processing Record 32 of set 15 | muroto
# Processing Record 33 of set 15 | alyangula
# Processing Record 34 of set 15 | myitkyina
# Processing Record 35 of set 15 | seddon
# Processing Record 36 of set 15 | kristiinankaupunki
# Processing Record 37 of set 15 | nador
# Processing Record 38 of set 15 | kartuzy
# Processing Record 39 of set 15 | songea
# Processing Record 40 of set 15 | gayeri
# Processing Record 41 of set 15 | iralaya
# Processing Record 42 of set 15 | lhokseumawe
# Processing Record 43 of set 15 | goure
# Processing Record 44 of set 15 | henties bay
# Processing Record 45 of set 15 | mount pleasant
# Processing Record 46 of set 15 | aktash
# Processing Record 47 of set 15 | ximei
# Processing Record 48 of set 15 | senador jose porfirio
# Processing Record 49 of set 15 | tefe
# Processing Record 50 of set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of set 16 | belmonte
# Processing Record 2 of set 16 | ofunato
# Processing Record 3 of set 16 | dosso
# Processing Record 4 of set 16 | sarh
# Processing Record 5 of set 16 | zaraza
# Processing Record 6 of set 16 | changji
# Processing Record 7 of set 16 | benjamin hill
# Processing Record 8 of set 16 | sabaudia
# Processing Record 9 of set 16 | havre
# Processing Record 10 of set 16 | nisia floresta
# Processing Record 11 of set 16 | geresk
# City not found. Skipping...
# Processing Record 12 of set 16 | badnawar
# Processing Record 13 of set 16 | caravelas
# Processing Record 14 of set 16 | meuselwitz
# Processing Record 15 of set 16 | pouebo
# Processing Record 16 of set 16 | saint-pierre
# Processing Record 17 of set 16 | yulara
# Processing Record 18 of set 16 | kralendijk
# Processing Record 19 of set 16 | oudtshoorn
# Processing Record 20 of set 16 | hamilton
# Processing Record 21 of set 16 | san miguel
# Processing Record 22 of set 16 | chagda
# City not found. Skipping...
# Processing Record 23 of set 16 | yendi
# Processing Record 24 of set 16 | melfort
# Processing Record 25 of set 16 | puerto escondido
# Processing Record 26 of set 16 | sidi ali
# Processing Record 27 of set 16 | sirjan
# Processing Record 28 of set 16 | kawai
# Processing Record 29 of set 16 | emerald
# Processing Record 30 of set 16 | nagycserkesz
# Processing Record 31 of set 16 | tobol
# Processing Record 32 of set 16 | vestmannaeyjar
# Processing Record 33 of set 16 | spanish fork
# Processing Record 34 of set 16 | kemijarvi
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
len(city_data)
# Out:
# 727

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Tera      NE  14.0078    0.7531     92.39        39          99
# 1  Alice Springs      AU -23.7000  133.8833     35.15        75           0
# 2      Jamestown      US  42.0970  -79.2353     85.01        53          75
# 3    Honningsvag      NO  70.9821   25.9704     56.95        94         100
# 4           Teya      RU  60.3778   92.6267     51.55        95          48
#
#    Wind Speed Current Description
# 0        7.52     overcast clouds
# 1        0.00           clear sky
# 2       18.41       broken clouds
# 3        0.00          light rain
# 4        2.89    scattered clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label = "City_ID")
